# %% [markdown]
# # Data Preparation

# %%
#Import LIbraries
import sqlite3
import pandas as pd

# Membuat koneksi ke basis data SQLite
conn = sqlite3.connect('jobdb.sqlite')

# %%
# Membuat objek cursor
cursor = conn.cursor()

# Mengeksekusi query untuk mendapatkan daftar tabel
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

# Mengambil hasil query
tables = cursor.fetchall()

# Menampilkan daftar tabel
for table in tables:
    print(table[0])
# Out:
# job_main
# job_req_edu
# job_location
# job_category
# job_type

# %%
datajob = pd.read_csv("responsibilities.csv")
datajob
# Out:
#       Unnamed: 0                                     responsibility
# 0              0  Design and influence a PR strategy and SMART P...
# 1              1  Ensure consistent and relevant customer commun...
# 2              2  Research, write press releases and ensure that...
# 3              3  Maintain relationships with influential lifest...
# 4              4  Manage photo shoots within the hotel for fashi...
# ...          ...                                                ...
# 1820        1820  Plan, manage and execute campaigns focused on ...
# 1821        1821  Responsible for maintaining and updating the c...
# 1822        1822  Prepare and upload product listing including c...
# 1823        1823  Receive and respond to E-commerce customer inq...
# 1824        1824  Manage E-commerce customer's comments and reviews
#
# [1825 rows x 2 columns]

# %% [markdown]
# ## Read all of the table and load the data into dataframe

# %%
# Membaca keseluruhan tabel dan memuatnya ke dalam DataFrame
query = 'SELECT * FROM job_main;'
datamain = pd.read_sql_query(query, conn)
datamain.head(20)
# Out:
#     scrapedid  webid  companyid                date_scraped  \
# 0          16      1       16.0  2022-03-29 08:59:56.687006
# 1          17      1       17.0  2022-03-29 08:59:56.687006
# 2          24      2       24.0  2022-03-29 09:00:03.610569
# 3          45      1       47.0  2022-03-29 08:59:56.687006
# 4          59      1       61.0  2022-03-29 08:59:56.687006
# 5         124      1      126.0  2022-03-29 08:59:56.687006
# 6         159      2      161.0  2022-03-29 09:00:03.610569
# 7         186      2      188.0  2022-03-29 09:00:03.610569
# 8         206      2      208.0  2022-03-29 09:00:03.610569
# 9         218      2      220.0  2022-03-29 09:00:03.610569
# 10        219      2      221.0  2022-03-29 09:00:03.610569
# 11        221      2      223.0  2022-03-29 09:00:03.610569
# 12        228      2      230.0  2022-03-29 09:00:03.610569
# 13        229      2      231.0  2022-03-29 09:00:03.610569
# 14        231      2      233.0  2022-03-29 09:00:03.610569
# ...

# %%
# Membaca keseluruhan tabel dan memuatnya ke dalam DataFrame
query = 'SELECT * FROM job_req_edu;'
dataedu = pd.read_sql_query(query, conn)
dataedu
# Out:
#         scrapedid                       requirement
# 0          776736                           diploma
# 1          776736               professional degree
# 2          776736             post graduate diploma
# 3          776736                 bachelor's degree
# 4          776736  advanced/higher/graduate diploma
# ...           ...                               ...
# 110672     237446               professional degree
# 110673     237446  advanced/higher/graduate diploma
# 110674     237446                 bachelor's degree
# 110675     237446             post graduate diploma
# 110676     237446                           diploma
#
# [110677 rows x 2 columns]

# %%
# Membaca keseluruhan tabel dan memuatnya ke dalam DataFrame
query = 'SELECT * FROM job_location;'
dataloc = pd.read_sql_query(query, conn)
dataloc
# Out:
#        scrapedid                    location
# 0         776736            klang/port klang
# 1         180838          selayang, selangor
# 2         911238                kuala lumpur
# 3        2910070               petaling jaya
# 4           6844                kuala lumpur
# ...          ...                         ...
# 63429    2622625                        sibu
# 63430     333340                       perai
# 63431       1366                      outram
# 63432     619213  tai seng - cc11, singapore
# 63433     237446                     central
#
# [63434 rows x 2 columns]

# %%
# Membaca keseluruhan tabel dan memuatnya ke dalam DataFrame
query = 'SELECT * FROM job_category;'
datacategory = pd.read_sql_query(query, conn)
datacategory
# Out:
#         scrapedid                    category
# 0          911238             sales/marketing
# 1          911238           digital marketing
# 2            6844             sales/marketing
# 3            6844  sales - financial services
# 4          334158         marketing executive
# ...           ...                         ...
# 130295    2622625      marketing/business dev
# 130296    2622625             sales/marketing
# 130297     333340             sales/marketing
# 130298     333340           sales - corporate
# 130299     619213  sales / retail / marketing
#
# [130300 rows x 2 columns]

# %%
# Membaca keseluruhan tabel dan memuatnya ke dalam DataFrame
query = 'SELECT * FROM job_type;'
datatype = pd.read_sql_query(query, conn)
datatype
# Out:
#        scrapedid        type
# 0        2656811   full-time
# 1         911238   full-time
# 2        4273934   full time
# 3           6844   full-time
# 4        4140110   full time
# ...          ...         ...
# 60053     477653   full-time
# 60054    2622625   full-time
# 60055     333340    contract
# 60056     619213  contractor
# 60057     619213   full-time
#
# [60058 rows x 2 columns]

# %% [markdown]
# # Assesment Data

# %%
datamain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59971 entries, 0 to 59970
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   scrapedid            59971 non-null  int64
#  1   webid                59971 non-null  int64
#  2   companyid            59962 non-null  float64
#  3   date_scraped         59971 non-null  object
#  4   job_title            59971 non-null  object
#  5   date_posted          59971 non-null  object
#  6   career_level         42495 non-null  object
#  7   year_experience_min  25736 non-null  float64
#  8   year_experience_max  700 non-null    float64
#  9   currency             58154 non-null  object
#  10  salary_min           30455 non-null  float64
#  11  salary_max           30567 non-null  float64
#  12  remote               3492 non-null   float64
#  13  source               0 non-null      object
#  14  last_seen            59971 non-null  object
# ...

# %%
datamain.isna().sum()
# Out:
# scrapedid                  0
# webid                      0
# companyid                  9
# date_scraped               0
# job_title                  0
# date_posted                0
# career_level           17476
# year_experience_min    34235
# year_experience_max    59271
# currency                1817
# salary_min             29516
# salary_max             29404
# remote                 56479
# source                 59971
# last_seen                  0
# date_expired           59971
# dtype: int64

# %%
print("Jumlah duplikasi: ",datamain.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
datamain.describe()
# Out:
#           scrapedid         webid      companyid  year_experience_min  \
# count  5.997100e+04  59971.000000   59962.000000         25736.000000
# mean   1.602280e+06      4.859399  102655.429522             2.241141
# std    1.427056e+06      6.067576  123874.875402             1.505065
# min    1.600000e+01      1.000000       1.000000             0.000000
# 25%    1.978360e+05      1.000000   12069.000000             1.000000
# 50%    1.302502e+06      2.000000   43634.500000             2.000000
# 75%    2.877340e+06      9.000000  168720.000000             3.000000
# max    4.386010e+06     26.000000  494910.000000            20.000000
#
#        year_experience_max    salary_min    salary_max       remote
# count           700.000000  3.045500e+04  3.056700e+04  3492.000000
# mean              4.090000  2.333901e+05  3.443250e+05     0.080470
# std               7.662716  1.596821e+06  2.247474e+06     0.272058
# ...

# %%
datamain.nunique()
# Out:
# scrapedid              59971
# webid                     24
# companyid              26377
# date_scraped            1770
# job_title              18936
# date_posted            47114
# career_level              53
# year_experience_min       15
# year_experience_max        6
# currency                   4
# salary_min               321
# salary_max               440
# remote                     2
# source                     0
# last_seen              33568
# date_expired               0
# dtype: int64

# %%
dataedu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110677 entries, 0 to 110676
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   scrapedid    110677 non-null  int64
#  1   requirement  110677 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 1.7+ MB

# %%
dataedu.isna().sum()
# Out:
# scrapedid      0
# requirement    0
# dtype: int64

# %%
print("Jumlah Duplikasi",dataedu.duplicated().sum())
# Out:
# Jumlah Duplikasi 0

# %%
dataedu.requirement.value_counts().head(20)
# Out:
# requirement
# not specified                                                                              19569
# bachelor's degree                                                                          18140
# post graduate diploma                                                                      15049
# professional degree                                                                        15047
# diploma                                                                                    14258
# advanced/higher/graduate diploma                                                           12811
# master's degree                                                                             2037
# diploma / advanced diploma / higher graduate diploma / dvm / dkm level 4 / dlkm level 5     1600
# professional certificate                                                                    1443
# ...

# %%
dataloc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63434 entries, 0 to 63433
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   scrapedid  63434 non-null  int64
#  1   location   63434 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 991.3+ KB

# %%
dataloc.isna().sum()
# Out:
# scrapedid    0
# location     0
# dtype: int64

# %%
dataloc.duplicated().sum()
# Out:
# 0

# %%
datacategory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130300 entries, 0 to 130299
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   scrapedid  130300 non-null  int64
#  1   category   130300 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 2.0+ MB

# %%
datacategory.isna().sum()
# Out:
# scrapedid    0
# category     0
# dtype: int64

# %%
datacategory.duplicated().sum()
# Out:
# 0

# %%
datatype.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60058 entries, 0 to 60057
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   scrapedid  60058 non-null  int64
#  1   type       60058 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 938.5+ KB

# %%
datacategory.isna().sum()
# Out:
# scrapedid    0
# category     0
# dtype: int64

# %%
datacategory.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# ## Drop Empty Column and Unnecessary Column

# %%
datamain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59971 entries, 0 to 59970
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   scrapedid            59971 non-null  int64
#  1   webid                59971 non-null  int64
#  2   companyid            59962 non-null  float64
#  3   date_scraped         59971 non-null  object
#  4   job_title            59971 non-null  object
#  5   date_posted          59971 non-null  object
#  6   career_level         42495 non-null  object
#  7   year_experience_min  25736 non-null  float64
#  8   year_experience_max  700 non-null    float64
#  9   currency             58154 non-null  object
#  10  salary_min           30455 non-null  float64
#  11  salary_max           30567 non-null  float64
#  12  remote               3492 non-null   float64
#  13  source               0 non-null      object
#  14  last_seen            59971 non-null  object
# ...

# %%
droptable = ['webid', 'companyid', 'date_scraped', 'date_posted', 'source', 'last_seen', 'date_expired']
datamain = datamain.drop(labels=droptable, axis=1)

# %%
datamain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59971 entries, 0 to 59970
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   scrapedid            59971 non-null  int64
#  1   job_title            59971 non-null  object
#  2   career_level         42495 non-null  object
#  3   year_experience_min  25736 non-null  float64
#  4   year_experience_max  700 non-null    float64
#  5   currency             58154 non-null  object
#  6   salary_min           30455 non-null  float64
#  7   salary_max           30567 non-null  float64
#  8   remote               3492 non-null   float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# ## Change Data Type

# %%
# Fungsi untuk memeriksa apakah nilai adalah bilangan desimal
def is_decimal(value):
    if isinstance(value, float):
        return value % 1 != 0 and value % 0.1 != 0 and value != 0
    return False

# Memeriksa kolom 'A' untuk keberadaan bilangan desimal
decimal_values_min = datamain['salary_min'].apply(lambda x: is_decimal(x))
decimal_values_max = datamain['salary_max'].apply(lambda x: is_decimal(x))

datamain['Decimal with Nonzero min'] = decimal_values_min
datamain['Decimal with Nonzero max'] = decimal_values_min

# Menampilkan DataFrame
datamain.head(20)
# Out:
#     scrapedid                                          job_title  \
# 0          16                        Digital Marketing Executive
# 1          17                Credit Control Executive / Regional
# 2          24                                  Credit Controller
# 3          45         Digital Marketing Accounts Executive (SEO)
# 4          59    Account Executive (Marketing agency / up to 3k)
# 5         124  Account Executive (Taiwan market) - Tableau (J...
# 6         159                           Marketing Executive (KL)
# 7         186                                   Internship in IT
# 8         206                          Sales Marketing Executive
# 9         218                         Senior Marketing Executive
# 10        219                        Digital Marketing Executive
# 11        221                                Marketing Executive
# 12        228                 Marketing Communications Executive
# ...

# %%
int_columns = ["year_experience_min", "year_experience_max", "salary_min", "salary_max", "remote"]

for column in int_columns:
    datamain[column] = pd.to_numeric(datamain[column], errors='coerce').fillna(0).astype(int)

# %%
datamain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59971 entries, 0 to 59970
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   scrapedid                 59971 non-null  int64
#  1   job_title                 59971 non-null  object
#  2   career_level              42495 non-null  object
#  3   year_experience_min       59971 non-null  int32
#  4   year_experience_max       59971 non-null  int32
#  5   currency                  58154 non-null  object
#  6   salary_min                59971 non-null  int32
#  7   salary_max                59971 non-null  int32
#  8   remote                    59971 non-null  int32
#  9   Decimal with Nonzero min  59971 non-null  bool
#  10  Decimal with Nonzero max  59971 non-null  bool
# dtypes: bool(2), int32(5), int64(1), object(3)
# memory usage: 3.1+ MB

# %%
datamain.nunique()
# Out:
# scrapedid                   59971
# job_title                   18936
# career_level                   53
# year_experience_min            15
# year_experience_max             7
# currency                        4
# salary_min                    321
# salary_max                    438
# remote                          2
# Decimal with Nonzero min        2
# Decimal with Nonzero max        2
# dtype: int64

# %%
column = ["Decimal with Nonzero min", "Decimal with Nonzero max"]
datamain.drop(labels=column, axis=1, inplace=True)

# %% [markdown]
# ## Missing Values

# %%
datamain.isna().sum()
# Out:
# scrapedid                  0
# job_title                  0
# career_level           17476
# year_experience_min        0
# year_experience_max        0
# currency                1817
# salary_min                 0
# salary_max                 0
# remote                     0
# dtype: int64

# %%
datamain.career_level.value_counts()
# Out:
# career_level
# Junior Executive                                     13967
# Not Specified                                        13949
# Senior Executive                                      6568
# Staff (non-management & non-supervisor)               2780
# Entry Level                                           2274
# Supervisor/Coordinator                                 637
# Manager                                                590
# Non-Executive                                          469
# Manager/Assistant Manager                              258
# Executive                                              238
# Senior Manager                                         200
# Less than 1 year experience                            186
# Entry Level / Junior, Apprentice                       105
# Associate / Supervisor                                  70
# Entry                                                   42
# Mid-Senior Level / Manager                              33
# ...

# %%
datamain[datamain.career_level.isna()]
# Out:
#        scrapedid                                          job_title  \
# 61           693                                       IT Developer
# 71          1014                          Sales Marketing Executive
# 125         1314  Marketing Executive Intern (Must apply at qame...
# 134         1355  Marketing Communication (EC Executive Karaoke ...
# 329         2411  Marketing and Business Development Executive (...
# ...          ...                                                ...
# 59966    4384856                                Marketing Executive
# 59967    4385152                        Marketing & Sales Executive
# 59968    4385526   Sales & Marketing Executive (Freight Forwarding)
# 59969    4385734                                Marketing Executive
# 59970    4386010                                Marketing Executive
#
#       career_level  year_experience_min  year_experience_max currency  \
# 61            None                    1                    3     None
# ...

# %%
datamain['career_level'].fillna(value="Not Specified", inplace=True)

# %%
datamain.isna().sum()
# Out:
# scrapedid                 0
# job_title                 0
# career_level              0
# year_experience_min       0
# year_experience_max       0
# currency               1817
# salary_min                0
# salary_max                0
# remote                    0
# dtype: int64

# %%
datamain[datamain.currency.isna()]
# Out:
#        scrapedid                                          job_title  \
# 61           693                                       IT Developer
# 71          1014                          Sales Marketing Executive
# 125         1314  Marketing Executive Intern (Must apply at qame...
# 134         1355  Marketing Communication (EC Executive Karaoke ...
# 141         1386  Senior / Executive, Marketing  (6 months contr...
# ...          ...                                                ...
# 59963    4384694                                MARKETING EXECUTIVE
# 59964    4384765  Marketing Communication Executive (Property Ma...
# 59966    4384856                                Marketing Executive
# 59969    4385734                                Marketing Executive
# 59970    4386010                                Marketing Executive
#
#            career_level  year_experience_min  year_experience_max currency  \
# ...

# %%
datamain['currency'].fillna(value="Unknown", inplace=True)
datamain
# Out:
#        scrapedid                                         job_title  \
# 0             16                       Digital Marketing Executive
# 1             17               Credit Control Executive / Regional
# 2             24                                 Credit Controller
# 3             45        Digital Marketing Accounts Executive (SEO)
# 4             59   Account Executive (Marketing agency / up to 3k)
# ...          ...                                               ...
# 59966    4384856                               Marketing Executive
# 59967    4385152                       Marketing & Sales Executive
# 59968    4385526  Sales & Marketing Executive (Freight Forwarding)
# 59969    4385734                               Marketing Executive
# 59970    4386010                               Marketing Executive
#
#            career_level  year_experience_min  year_experience_max currency  \
# 0         Not Specified                    0                    0      SGD
# ...

# %%
datamain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59971 entries, 0 to 59970
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   scrapedid            59971 non-null  int64
#  1   job_title            59971 non-null  object
#  2   career_level         59971 non-null  object
#  3   year_experience_min  59971 non-null  int32
#  4   year_experience_max  59971 non-null  int32
#  5   currency             59971 non-null  object
#  6   salary_min           59971 non-null  int32
#  7   salary_max           59971 non-null  int32
#  8   remote               59971 non-null  int32
# dtypes: int32(5), int64(1), object(3)
# memory usage: 3.0+ MB

# %%
datamain = datamain[datamain['salary_min'] != 0]
datamain
# Out:
#        scrapedid                                         job_title  \
# 3             45        Digital Marketing Accounts Executive (SEO)
# 4             59   Account Executive (Marketing agency / up to 3k)
# 8            206                         Sales Marketing Executive
# 10           219                       Digital Marketing Executive
# 11           221                               Marketing Executive
# ...          ...                                               ...
# 59960    4384036             Junior Area Sales Marketing Executive
# 59961    4384073                               Marketing Executive
# 59965    4384771           Marketing Executive (Cosmetics Product)
# 59967    4385152                       Marketing & Sales Executive
# 59968    4385526  Sales & Marketing Executive (Freight Forwarding)
#
#            career_level  year_experience_min  year_experience_max currency  \
# 3      Junior Executive                    1                    0      SGD
# ...

# %% [markdown]
# # Explore Database

# %%
datamain.currency.value_counts()
# Out:
# currency
# MYR    10515
# SGD     9684
# RM      4921
# IDR     1256
# Name: count, dtype: int64

# %%
datamain_result = pd.merge(datamain, dataloc, how="left", on="scrapedid").merge(datatype, how="left", on="scrapedid")
    
datamain_result.head(50)
# Out:
#     scrapedid                                          job_title  \
# 0          45         Digital Marketing Accounts Executive (SEO)
# 1          59    Account Executive (Marketing agency / up to 3k)
# 2         206                          Sales Marketing Executive
# 3         219                        Digital Marketing Executive
# 4         221                                Marketing Executive
# 5         228                 Marketing Communications Executive
# 6         229                        Digital Marketing Executive
# 7         231                        Digital Marketing Executive
# 8         257  IT Digital Transformation Head (Fast Food Chai...
# 9         257  IT Digital Transformation Head (Fast Food Chai...
# 10        259                                Marketing Executive
# 11        274                 Senior Digital Marketing Executive
# 12        293                                Marketing Executive
# ...

# %%
datamain_result.currency.value_counts()
# Out:
# currency
# MYR    11793
# SGD     9996
# RM      5135
# IDR     1528
# Name: count, dtype: int64

# %%
datamain_result.duplicated().sum()
# Out:
# 0

# %%
# Save DataFrame into excel file
excel_file_path = 'datacompleted.xlsx'
datamain_result.to_excel(excel_file_path, index=False)

# %%
datamain_result.year_experience_min.value_counts()
# Out:
# year_experience_min
# 0     12938
# 1      5667
# 2      5410
# 3      3153
# 5       790
# 4       369
# 10       44
# 6        33
# 8        26
# 7        14
# 12        3
# 9         2
# 15        2
# 20        1
# Name: count, dtype: int64

# %%
# Import library
from scipy import stats

# Set float format options
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# Function to calculate mode
def calculate_mode(x):
    return stats.mode(x)[0][0] if len(x) > 0 else None

explore = datamain_result.groupby(by=["year_experience_min", "currency", "career_level"]).agg({
    "salary_min": ["max", "min", "mean", "std", "median", calculate_mode],
    "salary_max": ["max", "min", "mean", "std", "median", calculate_mode]
})

# Convert mode value to sentence
explore[("salary_min", "mode")] = explore[("salary_min", "calculate_mode")].apply(lambda x: f"{x}")
explore[("salary_max", "mode")] = explore[("salary_max", "calculate_mode")].apply(lambda x: f"{x}")

# Drop lambda function columns
explore.drop([("salary_min", "calculate_mode"), ("salary_max", "calculate_mode")], axis=1, inplace=True)

# Print the DataFrame
explore_result = explore.query("currency == 'IDR'")
explore_result
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_17448\659901996.py:9: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   return stats.mode(x)[0][0] if len(x) > 0 else None
#                                                                      salary_min  \
#                                                                             max
# year_experience_min currency career_level
# 0                   IDR      Less than 1 year experience                7500000
#                              Not Specified                             20000000
#                              Staff (non-management & non-supervisor)   10000000
# ...

# %%
salary_check = datamain_result.query("salary_min == 30000000")
salary_check
# Out:
#        scrapedid                      job_title  \
# 1789       73262   Stockist dan Audit Inventory
# 3558      124695  Head of Credit Risk - Banking
# 13277    1358246            Marketing Executive
#
#                                   career_level  year_experience_min  \
# 1789                             Not Specified                    1
# 3558                           risk management                    0
# 13277  Staff (non-management & non-supervisor)                    1
#
#        year_experience_max currency  salary_min  salary_max  remote location  \
# 1789                     3      IDR    30000000    40000000       0  jakarta
# 3558                     0      IDR    30000000    50000000       0  jakarta
# 13277                    0      IDR    30000000    50000000       0   bekasi
#
#             type
# 1789   full_time
# 3558   permanent
# 13277  full-time

# %%
salary_check = datamain_result.query("salary_min == 170000000")
salary_check
# Out:
#       scrapedid            job_title   career_level  year_experience_min  \
# 1540      61163  Marketing Executive  Not Specified                    1
#
#       year_experience_max currency  salary_min  salary_max  remote location  \
# 1540                    3      IDR   170000000   200000000       1  jakarta
#
#            type
# 1540  full_time

# %%
salary_check = datamain_result.query("salary_min == 20000000")
salary_check
# Out:
#        scrapedid                        job_title            career_level  \
# 587        15844               IT Product Manager           Not Specified
# 1027       39090     IT System Security Engineer            Not Specified
# 1354       52555  Dokter Spesialis Penyakit Dalam           Not Specified
# 1525       59636                    VP IT Product           Not Specified
# 18271    2327187              Marketing Executive  Supervisor/Coordinator
# 18272    2327187              Marketing Executive  Supervisor/Coordinator
# 18273    2327187              Marketing Executive  Supervisor/Coordinator
# 20114    2831595      Digital Marketing Executive  Supervisor/Coordinator
# 20115    2831595      Digital Marketing Executive  Supervisor/Coordinator
# 20116    2831595      Digital Marketing Executive  Supervisor/Coordinator
# 28428    4377807        TRADE MARKETING EXECUTIVE           Not Specified
#
#        year_experience_min  year_experience_max currency  salary_min  \
# ...

# %%
# Import library
from scipy import stats

# Set float format options
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# Function to calculate mode
def calculate_mode(x):
    return stats.mode(x)[0][0] if len(x) > 0 else None

explore = datamain_result.groupby(by=["year_experience_min", "currency", "career_level"]).agg({
    "salary_min": ["max", "min", "mean", "std", "median", calculate_mode],
    "salary_max": ["max", "min", "mean", "std", "median", calculate_mode]
})

# Convert mode value to sentence
explore[("salary_min", "mode")] = explore[("salary_min", "calculate_mode")].apply(lambda x: f"{x}")
explore[("salary_max", "mode")] = explore[("salary_max", "calculate_mode")].apply(lambda x: f"{x}")

# Drop lambda function columns
explore.drop([("salary_min", "calculate_mode"), ("salary_max", "calculate_mode")], axis=1, inplace=True)

# Print the DataFrame
explore_result = explore.query("currency == 'SGD'")
explore_result
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_17448\1169777624.py:9: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   return stats.mode(x)[0][0] if len(x) > 0 else None
#                                                                      salary_min  \
#                                                                             max
# year_experience_min currency career_level
# 0                   SGD      Entry Level                                   4910
#                              Junior Executive                              5000
#                              Manager                                       7000
# ...

# %%
# Import library
from scipy import stats

# Set float format options
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# Function to calculate mode
def calculate_mode(x):
    return stats.mode(x)[0][0] if len(x) > 0 else None

explore = datamain_result.groupby(by=["year_experience_min", "currency", "career_level"]).agg({
    "salary_min": ["max", "min", "mean", "std", "median", calculate_mode],
    "salary_max": ["max", "min", "mean", "std", "median", calculate_mode]
})

# Convert mode value to sentence
explore[("salary_min", "mode")] = explore[("salary_min", "calculate_mode")].apply(lambda x: f"{x}")
explore[("salary_max", "mode")] = explore[("salary_max", "calculate_mode")].apply(lambda x: f"{x}")

# Drop lambda function columns
explore.drop([("salary_min", "calculate_mode"), ("salary_max", "calculate_mode")], axis=1, inplace=True)

# Print the DataFrame
explore_result = explore.query("currency == 'RM'")
explore_result
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_17448\571524233.py:9: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   return stats.mode(x)[0][0] if len(x) > 0 else None
#                                            salary_min                        \
#                                                   max   min    mean     std
# year_experience_min currency career_level
# 0                   RM       Executive           8500   150 2090.51 1229.11
#                              Non-Executive       2100    75 1357.44  536.03
#                              Not Specified     120000     1 3012.63 3931.09
# ...

# %%
# Import library
from scipy import stats

# Set float format options
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# Function to calculate mode
def calculate_mode(x):
    return stats.mode(x)[0][0] if len(x) > 0 else None

explore = datamain_result.groupby(by=["year_experience_min", "currency", "career_level"]).agg({
    "salary_min": ["max", "min", "mean", "std", "median", calculate_mode],
    "salary_max": ["max", "min", "mean", "std", "median", calculate_mode]
})

# Convert mode value to sentence
explore[("salary_min", "mode")] = explore[("salary_min", "calculate_mode")].apply(lambda x: f"{x}")
explore[("salary_max", "mode")] = explore[("salary_max", "calculate_mode")].apply(lambda x: f"{x}")

# Drop lambda function columns
explore.drop([("salary_min", "calculate_mode"), ("salary_max", "calculate_mode")], axis=1, inplace=True)

# Print the DataFrame
explore_result = explore.query("currency == 'MYR'")
explore_result
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_17448\2158953837.py:9: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   return stats.mode(x)[0][0] if len(x) > 0 else None
#                                               salary_min                  \
#                                                      max    min     mean
# year_experience_min currency career_level
# 0                   MYR      Entry Level            6500    300  2920.29
#                              Junior Executive       5000    800  2625.45
#                              Manager                2000   2000  2000.00
# ...

# %% [markdown]
# ## Explore Data Responsibilities

# %%
datajob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1825 entries, 0 to 1824
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1825 non-null   int64
#  1   responsibility  1825 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 28.6+ KB

# %%
datajob.isna().sum()
# Out:
# Unnamed: 0        0
# responsibility    0
# dtype: int64

# %%
datajob.duplicated().sum()
# Out:
# 0

# %%
datajob.nunique()
# Out:
# Unnamed: 0        1825
# responsibility    1795
# dtype: int64

# %%
datajob.responsibility.value_counts().head(10)
# Out:
# responsibility
# Other ad-hoc duties as assigned                                                                                                      4
# Brainstorms new and creative growth strategies through digital marketing.                                                            2
# Designs, builds, and maintains our social media presence.                                                                            2
# Evaluates emerging technologies.                                                                                                     2
# Identifies critical conversion points and drop off points and optimizes user funnels.                                                2
# Utilizes strong analytical ability to evaluate end-to-end customer experience across multiple channels and customer touch points.    2
# Collaborates with internal teams to create landing pages and optimize user experience.                                               2
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize
from collections import Counter

# Menggabungkan semua teks menjadi satu teks
all_text = ' '.join(datajob['responsibility'])

# Memisahkan teks menjadi token (kata-kata atau kalimat)
tokens = word_tokenize(all_text)

# Menghitung frekuensi masing-masing token
token_counter = Counter(tokens)

# Dapatkan 50 kata paling banyak digunakan
top_100_words = token_counter.most_common(100)

# Filter baris-baris yang mengandung salah satu dari 100 kata paling umum
filtered_data = datajob[datajob['responsibility'].str.contains('|'.join([word for word, count in top_100_words]))]

# Tampilkan hasil
print("100 kata paling banyak digunakan:", top_100_words)
# Out:
# 100 kata paling banyak digunakan: [('and', 1713), (',', 1074), ('to', 501), ('the', 481), ('marketing', 475), ('.', 426), ('with', 337), ('of', 328), ('for', 297), ('media', 246), ('in', 220), ('social', 205), ('campaigns', 172), ('on', 168), ('sales', 159), ('digital', 134), ('as', 112), ('content', 107), ('strategies', 106), ('brand', 100), ('company', 98), ('all', 97), ('market', 96), ('&', 96), ('customer', 92), ('Manage', 87), ('other', 84), ('new', 79), ('activities', 76), ('events', 76), ('team', 71), ('online', 71), ('product', 71), ('platforms', 68), ('a', 66), ('performance', 65), ('channels', 64), ('’', 64), ('business', 63), ('materials', 62), ('Assist', 62), ('website', 58), ('including', 58), ('research', 57), ('customers', 57), ('by', 56), ('Develop', 55), ('(', 55), (')', 55), ('execute', 55), ('trends', 55), ('various', 52), ('management', 52), ('assigned', 52), ('campaign', 51), ('products', 51), ('ensure', 50), ('Plan', 49), ('manage', 48), ('duties', 47), ('across
# ...

# %%
# Analyze the responsibilities
responsibilities = datajob['responsibility']

# Identify potential gig jobs based on keywords
gig_jobs_keywords = ['social media management', 'content creation', 'digital marketing', 'email marketing', 'SEO optimization', 'advertising', 
                     'Assistant Manager', 'Campaign management', 'Market research', 'Brand management', 'Public relations', 'Sales and marketing',
                     'Lead generation', 'Marketing strategy', 'Market segmentation', 'Competitor analysis']

# Membuat DataFrame dari list
df_keywords = pd.DataFrame({'Gig Jobs Keywords': gig_jobs_keywords})

# Buat tabel
# Inisialisasi DataFrame untuk hasil
result_df = pd.DataFrame(columns=['Gig Jobs Keywords', 'responsibility'])

# Loop melalui setiap kata kunci
for keyword in df_keywords['Gig Jobs Keywords']:
    # Gunakan str.contains untuk mencari kemunculan kata kunci dalam setiap kalimat
    mask = datajob['responsibility'].str.contains(keyword, case=False)
    # Filter kalimat yang mengandung kata kunci
    sentences_with_keyword = datajob[mask]
    # Tambahkan hasil pencarian ke dalam DataFrame hasil
    sentences_with_keyword['Gig Jobs Keywords'] = keyword
    result_df = pd.concat([result_df, sentences_with_keyword[['Gig Jobs Keywords', 'responsibility']]], ignore_index=True)

# Kelompokkan kalimat berdasarkan kata kunci
grouped_df = result_df.groupby('Gig Jobs Keywords')['responsibility'].apply(list).reset_index()

# Hitung jumlah responsibilitas yang mengandung setiap kata kunci
grouped_df['Total'] = grouped_df['responsibility'].apply(lambda x: len(x))

# Tampilkan hasil
grouped_df.sort_values(by='Total', ascending=False)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_17448\2471248403.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentences_with_keyword['Gig Jobs Keywords'] = keyword
# C:\Users\Acer\AppData\Local\Temp\ipykernel_17448\2471248403.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentences_with_keyword['Gig Jobs Keywords'] = keyword
# C:\Users\Acer\AppData\Local\Temp\ipykernel_17448\2471248403.py:23: SettingWithCopyWarning:
# ...
